# %%
from keras.preprocessing.text import one_hot, Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Input, GlobalAveragePooling1D
from keras.layers import Flatten, Dot
from keras.layers.embeddings import Embedding
from keras.models import Model
from umap import UMAP
from sklearn.neighbors import NearestNeighbors
from tokens_and_glov_embs import get_docs
import numpy as np
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
import pickle, random, glob

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Process and Visualize Embeddings

# %% [markdown]
# ### Load GloVe Embedding Matrix and Tokenizer

# %%
embedding_matrix = np.load('../preprocessing/glov_emb_matrix.npy')
print('Embedding Matrix:', embedding_matrix.shape)

with open('../preprocessing/tokenizer.pkl', 'rb') as f:
    t = pickle.load(f)
# Out:
# Embedding Matrix: (578207, 100)

# %% [markdown]
# ### GloVe Embedding Model with 1D Global Average Pooling

# %%
vocab_size = 578207
input_length = 10000

# sole glov model
input_tens = Input(shape=(input_length,), name='input_1')
x = Embedding(
    vocab_size, 
    100, 
    input_length=input_length, 
    weights=[embedding_matrix],
    trainable=False
)(input_tens)
#x = Flatten()(x)
x = GlobalAveragePooling1D()(x)

model = Model(inputs=input_tens, outputs=x)
model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 10000)             0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, 10000, 100)        57820700
# _________________________________________________________________
# global_average_pooling1d_1 ( (None, 100)               0
# =================================================================
# Total params: 57,820,700
# Trainable params: 0
# Non-trainable params: 57,820,700
# _________________________________________________________________

# %% [markdown]
# ### Predict Embeddings for all Works

# %%
embeddings = np.asarray(()) 
num_data_files = len(glob.glob('../data/Gutenberg/txt/*'))
for d in range(0, num_data_files + 1, 100):
    padded_docs = get_docs('../data/Gutenberg/txt/', t, d, d+100)
    sub_embs = model.predict(padded_docs, verbose=1)
    if embeddings.size == 0:
        embeddings = sub_embs
    else:
        embeddings = np.vstack((embeddings, sub_embs))
    
    print('Embeddings:', embeddings.shape)
# Out:
# 100/100 [==============================] - 0s 3ms/step
# Embeddings: (100, 100)
# 100/100 [==============================] - 0s 3ms/step
# Embeddings: (200, 100)
# 100/100 [==============================] - 0s 3ms/step
# Embeddings: (300, 100)
# 100/100 [==============================] - 0s 3ms/step
# Embeddings: (400, 100)
# 100/100 [==============================] - 0s 3ms/step
# Embeddings: (500, 100)
# 100/100 [==============================] - 0s 3ms/step
# Embeddings: (600, 100)
# 100/100 [==============================] - 0s 3ms/step
# Embeddings: (700, 100)
# 100/100 [==============================] - 0s 3ms/step
# Embeddings: (800, 100)
# 100/100 [==============================] - 0s 3ms/step
# Embeddings: (900, 100)
# 100/100 [==============================] - 0s 3ms/step
# Embeddings: (1000, 100)
# 100/100 [==============================] - 0s 3ms/step
# Embeddings: (1100, 100)
# 100/100 [==============================] - 0s 3ms/step
# Embeddings: (1200, 100)
# 100/100 [==============================] - 0s 3ms/step
# Embeddings: (1300, 100)
# 100/100 [==============================] - 0s 3ms/step
# Embeddings: (1400, 100)
# 100/100 [==============================] - 0s 3ms/step
# Embeddings: (1500, 100)
# 100/100 [==============================] - 0s 3ms/step
# Embeddings: (1600, 100)
# 100/100 [==============================] - 0s 3ms/step
# Embeddings: (1700, 100)
# 100/100 [==============================] - 0s 3ms/step
# Embeddings: (1800, 100)
# 100/100 [==============================] - 0s 3ms/step
# Embeddings: (1900, 100)
# 100/100 [==============================] - 0s 3ms/step
# Embeddings: (2000, 100)
# 100/100 [==============================] - 0s 3ms/step
# Embeddings: (2100, 100)
# 100/100 [==============================] - 0s 3ms/step
# Embeddings: (2200, 100)
# 100/100 [==============================] - 0s 3ms/step
# Embeddings: (2300, 100)
# 100/100 [==============================] - 0s 3ms/step
# Embeddings: (2400, 100)
# 100/100 [==============================] - 0s 3ms/step
# Embeddings: (2500, 100)
# 100/100 [==============================] - 0s 3ms/step
# Embeddings: (2600, 100)
# 100/100 [==============================] - 0s 3ms/step
# Embeddings: (2700, 100)
# 100/100 [==============================] - 0s 3ms/step
# Embeddings: (2800, 100)
# 100/100 [==============================] - 0s 3ms/step
# Embeddings: (2900, 100)
# 100/100 [==============================] - 0s 3ms/step
# Embeddings: (3000, 100)
# 36/36 [==============================] - 0s 3ms/step
# Embeddings: (3036, 100)

# %% [markdown]
# ### UMAP Embeddings for Visualization

# %%
umap = UMAP(n_neighbors=20, metric='cosine')
vis_embeddings = umap.fit_transform(embeddings)
print('Vis Embeddings:', vis_embeddings.shape)
# Out:
# Vis Embeddings: (3036, 2)

# %%
v2_author_df = pd.read_csv('../preprocessing/v1_author_df.csv')
v2_author_df['umap_1'] = vis_embeddings[:, 0]
v2_author_df['umap_2'] = vis_embeddings[:, 1]
v2_author_df.head(10)
# Out:
#    work_id                  author  \
# 0        0          Thomas_Carlyle
# 1        1            Daniel_Defoe
# 2        2   James_Fenimore_Cooper
# 3        3             Andrew_Lang
# 4        4              Mark_Twain
# 5        5          Wilkie_Collins
# 6        6  Robert_Louis_Stevenson
# 7        7            Thomas_Hardy
# 8        8    Edgar_Rice_Burroughs
# 9        9     Nathaniel_Hawthorne
#
#                                                 work     umap_1    umap_2
# 0   History_of_Friedrich_II_of_Prussia,_Appendix.txt -13.398980  0.375710
# 1  The_Life,_Adventures_&_Piracies_of_the_Famous_...  -2.697822 -2.966858
# 2                              Afloat_And_Ashore.txt   1.164151  0.732139
# 3                                Custom_and_Myth.txt   1.721932  2.871000
# 4                Goldsmith's_Friend_Abroad_Again.txt -13.249290  0.394274
# 5                            The_Queen_of_Hearts.txt   0.461708 -0.220036
# 6  The_Works_of_Robert_Louis_Stevenson_-_Swanston...   1.245222 -3.846574
# 7                       Under_the_Greenwood_Tree.txt   1.374676 -2.406246
# 8                      The_Land_That_Time_Forgot.txt  -0.598880 -3.843706
# 9                             A_Bell's_Biography.txt -14.025440  1.224346

# %%
#fig, ax = plt.figure(figsize=(15,8))
v2_subset = v2_author_df[:1000]
fig = plt.figure(figsize=(15,8))
sns.scatterplot(x='umap_1', y='umap_2', hue='author', size='author', data=v2_author_df, alpha=0.6, legend='brief')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.10),
          fancybox=True, shadow=True, ncol=5)
plt.title('L1-TF-IDF Word Sampling Embeddings for Gutenberg Works with 10,000 Input Length')
plt.show()

# %% [markdown]
# ### Plotly Interactive Scatter Plot

# %%
fig = px.scatter(v2_author_df, x='umap_1', y='umap_2', color='author',
                 hover_data=['work'])
fig.show()
# Out:
# <div>
#
#
#             <div id="18a18542-ec45-4632-84b7-0180d7262c17" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("18a18542-ec45-4632-84b7-0180d7262c17")) {
#                     Plotly.newPlot(
#                         '18a18542-ec45-4632-84b7-0180d7262c17',
#                         [{"customdata": [["History_of_Friedrich_II_of_Prussia,_Appendix.txt"], ["History_of_Friedrich_II_of_Prussia,_Volume_16.txt"], ["History_of_Friedrich_II_of_Prussia,_Volume_14.txt"], ["Life_of_Robert_Burns.txt"], ["The_Life_of_John_Sterling.txt"], ["History_of_Friedrich_II_of_Prussia,_Volume_10.txt"], ["Latter-Day_Pamphlets.txt"], ["History_of_Friedrich_II_of_Prussia,_Volume_1.txt"], ["History_of_Friedrich_II_of_Prussia,_Volume_12.txt"], ["Sartor_Resartus.txt"], ["History_of_Friedrich_II_of_Prussia,_Volume_13.txt"], ["The_French_Revolution.txt"], ["History_of_Friedrich_II_of_Prussia,_Volume_20.txt"], ["History_of_Friedrich_II_of_Prussia,_Volume_2.txt"], ["History_of_Friedrich_II_of_Prussia,_Volume_5.txt"], ["History_of_Friedrich_II_of_Prussia,_Volume_21.txt"], ["Early_Kings_of_Norway.txt"], ["History_of_Friedrich_II_of_Prussia,_Volume_9.txt"], ["On_the_Choice_of_Books.txt"], ["History_of_Friedrich_II_of_Prussia,_Volume_19.txt"], ["Past_and_Present.txt"], ["History_of_Friedrich_II_of_Prussia,_Volume_15.txt"], ["History_of_Friedrich_II_of_Prussia,_Volume_18.txt"], ["History_of_Friedrich_II_of_Prussia,_Volume_17.txt"], ["The_Life_of_Friedrich_Schiller.txt"], ["History_of_Friedrich_II_of_Prussia,_Volume_4.txt"], ["History_of_Friedrich_II_of_Prussia,_Volume_7.txt"], ["Heroes_and_Hero_Worship.txt"], ["History_of_Friedrich_II_of_Prussia,_Volume_8.txt"], ["History_of_Friedrich_II_of_Prussia,_Volume_6.txt"], ["History_of_Friedrich_II_of_Prussia,_Volume_3.txt"], ["History_of_Friedrich_II_of_Prussia,_Volume_11.txt"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "author=Thomas_Carlyle<br>umap_1=%{x}<br>umap_2=%{y}<br>work=%{customdata[0]}", "legendgroup": "author=Thomas_Carlyle", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "author=Thomas_Carlyle", "showlegend": true, "type": "scattergl", "x": [-13.398980140686035, -2.03623628616333, -2.0793209075927734, 1.3761621713638306, 1.464630126953125, -1.9701849222183228, 1.1399692296981812, -1.968632459640503, -2.105731964111328, 2.7387564182281494, -2.061386823654175, 3.3720297813415527, -2.0856926441192627, -1.9728578329086304, -2.0031819343566895, -2.031406879425049, -1.5201184749603271, -2.0432350635528564, -0.2843132019042969, -2.0769081115722656, 3.2577812671661377, -2.1063010692596436, -2.1065564155578613, -2.070955276489258, 1.8943198919296265, -2.0273282527923584, -2.045811176300049, 1.7483985424041748, -2.005225658416748, -2.024064302444458, -2.004002571105957, -2.0266366004943848], "xaxis": "x", "y": [0.37570980191230774, 3.4602861404418945, 3.4978151321411133, 2.108442783355713, 1.051270842552185, 3.3952574729919434, 1.897847294807434, 3.3930389881134033, 3.5244626998901367, 0.09044795483350754, 3.4816319942474365, -0.3117847442626953, 3.5025527477264404, 3.4121172428131104, 3.4287562370300293, 3.4565200805664062, 3.096081256866455, 3.4667961597442627, 2.078447103500366, 3.4937782287597656, 0.19800342619419098, 3.5228490829467773, 3.5241804122924805, 3.48885440826416, 2.708230972290039, 3.449313163757324, 3.4657084941864014, 2.59724760055542, 3.4227988719940186, 3.44804048538208, 3.436772108078003, 3.451141834259033], "yaxis": "y"}, {"customdata": [["The_Life,_Adventures_&_Piracies_of_the_Famous_Captain_Singleton.txt"], ["An_Humble_Proposal_to_the_People_of_England.txt"], ["The_Life_and_Most_Surprising_Adventures_of_Robinson_Crusoe.txt"], ["The_Fortunes_and_Misfortunes_of_the_Famous_Moll_Flanders.txt"], ["Dickory_Cronke.txt"], ["The_Life_and_Adventures_of_Robinson_Crusoe_(1808).txt"], ["The_Life_and_Adventures_of_Robinson_Crusoe_Of_York,_Mariner,_Vol._1.txt"], ["A_Short_Narrative_of_the_Life_and_Actions_of_His_Grace_John,_D._of_Marlborogh.txt"], ["Military_Memoirs_of_Capt._George_Carleton.txt"], ["An_Answer_to_a_Question_that_Nobody_thinks_of,_viz.,_But_what_if_the_Queen_should_Die?.txt"], ["The_True-Born_Englishman.txt"], ["A_New_Voyage_Round_the_World_by_a_Course_Never_Sailed_Before.txt"], ["Second_Thoughts_are_Best.txt"] ...

# %% [markdown]
# # Nearest Neighbors for Works

# %% [markdown]
# ### Neighbors Search on 100-D Embeddings

# %%
#np.save('10000_embeddings.npy', embeddings)

# %%
# build data frame with neighbor, author, work
neighbors = NearestNeighbors(n_neighbors=11, metric='cosine').fit(embeddings)
distances, inds = neighbors.kneighbors(embeddings)
full_neighbors = []
for idx in range(inds.shape[0]):
    sub_inds = inds[idx, :].tolist()
    df_author_and_works = v2_author_df.iloc[sub_inds, 1:3]
    authors = df_author_and_works['author'].values
    works = df_author_and_works['work'].values
    authors_and_works = np.column_stack((works, authors)).tolist()
    row_neighbors = []
    for row in authors_and_works:
        row_neighbors.extend(row)
      
    full_neighbors.append(row_neighbors)

#random.shuffle(full_neighbors)
df_neighbors = pd.DataFrame(
    full_neighbors,
    columns=[
        'Query_Title', 'Query_Author',
        '1st_Match_Title', '1st_Match_Author',
        '2nd_Match_Title', '2nd_Match_Author',
        '3rd_Match_Title', '3rd_Match_Author',
        '4th_Match_Title', '4th_Match_Author',
        '5th_Match_Title', '5th_Match_Author',
        '6th_Match_Title', '6th_Match_Author',
        '7th_Match_Title', '7th_Match_Author',
        '8th_Match_Title', '8th_Match_Author',
        '9th_Match_Title', '9th_Match_Author',
        '10th_Match_Title', '10th_Match_Author',
    ]
)
#df_neighbors.head(30)
df_neighbors.sort_values(by=['Query_Title'], ascending=False).head(30)
#df_neighbors.to_csv('df_neighbors.csv', index=False)
# Out:
#                                Query_Title           Query_Author  \
# 56                               Youth.txt           Isaac_Asimov
# 1285                             Youth.txt          Joseph_Conrad
# 2177         Young_Hunters_of_the_Lake.txt     Edward_Stratemeyer
# 90        Young_Folks'_History_of_Rome.txt   Charlotte_Mary_Yonge
# 1441   Young_Folks'_History_of_England.txt   Charlotte_Mary_Yonge
# 2973                 Young_Auctioneers.txt     Edward_Stratemeyer
# 2325                You_Never_Can_Tell.txt    George_Bernard_Shaw
# 1922                  Yeast:_A_Problem.txt       Charles_Kingsley
# 1930                             Yeast.txt    Thomas_Henry_Huxley
# 244                             Xerxes.txt           Jacob_Abbott
# 1734                     Wyndham's_Pal.txt        Harold_Bindloss
# 2787                         Wyandotte.txt  James_Fenimore_Cooper
# 889                  Wuthering_Heights.txt           Emily_Bronte
# 2572                    Wulf_the_Saxon.txt    George_Alfred_Henty
# 3002                    Write_It_Right.txt         Ambrose_Bierce
# 287             Wrecked_but_not_Ruined.txt         R_M_Ballantyne
# 2288       Work:_A_Story_of_Experience.txt      Louisa_May_Alcott
# 1811       Woodstock;_or,_The_Cavalier.txt       Sir_Walter_Scott
# 2678               Wood_Folk_at_School.txt         William_J_Long
# 252                   Won_by_the_Sword.txt    George_Alfred_Henty
# 190                      Women_in_Love.txt           D_H_Lawrence
# 542                 Women_and_Politics.txt       Charles_Kingsley
# 2015  Wolfert's_Roost_and_Miscellanies.txt      Washington_Irving
# 2967                  Within_the_Tides.txt          Joseph_Conrad
# 1541   Within_the_Rim_and_Other_Essays.txt            Henry_James
# 358               With_Wolfe_in_Canada.txt    George_Alfred_Henty
# 1390               With_The_Night_Mail.txt        Rudyard_Kipling
# 892              With_Moore_At_Corunna.txt    George_Alfred_Henty
# 2144              With_Lee_in_Virginia.txt    George_Alfred_Henty
# 11        With_Kitchener_in_the_Soudan.txt    George_Alfred_Henty
#
#                                         1st_Match_Title  \
# 56                                    Mr._Spaceship.txt
# 1285                Dutch_Courage_and_Other_Stories.txt
# 2177                               Four_Boy_Hunters.txt
# 90        Aunt_Charlotte's_Stories_of_Greek_History.txt
# 1441                   A_Child's_History_of_England.txt
# 2973                        The_Young_Bridge-Tender.txt
# 2325                                        Candida.txt
# 1922                        Two_Years_Ago,_Volume_I.txt
# 1930        The_Present_Condition_of_Organic_Nature.txt
# 244                                        Hannibal.txt
# 1734                       Lister's_Great_Adventure.txt
# 2787                                      Satanstoe.txt
# 889                           The_Laughing_Cavalier.txt
# 2572                          Both_Sides_the_Border.txt
# 3002                Time_and_Tide_by_Weare_and_Tyne.txt
# 287                                 Fort_Desolation.txt
# 2288              Silver_Pitchers:_and_Independence.txt
# 1811                            Peveril_of_the_Peak.txt
# 2678                            Secret_of_the_Woods.txt
# 252                            In_the_Irish_Brigade.txt
# 190                                     The_Rainbow.txt
# 542                               A_Modest_Proposal.txt
# 2015                              The_Crayon_Papers.txt
# 2967  The_Twins_of_Table_Mountain_and_Other_Stories.txt
# 1541                               The_Middle_Years.txt
# 358                            True_to_the_Old_Flag.txt
# 1390                                    Sea_Warfare.txt
# 892                      Under_Wellington's_Command.txt
# 2144                           True_to_the_Old_Flag.txt
# 11                              At_Aboukir_and_Acre.txt
#
#            1st_Match_Author  \
# 56      Philip_Kindred_Dick
# 1285            Jack_London
# 2177     Edward_Stratemeyer
# 90     Charlotte_Mary_Yonge
# 1441        Charles_Dickens
# 2973     Edward_Stratemeyer
# 2325    George_Bernard_Shaw
# 1922       Charles_Kingsley
# 1930    Thomas_Henry_Huxley
# 244            Jacob_Abbott
# 1734        Harold_Bindloss
# 2787  James_Fenimore_Cooper
# 889         Baronness_Orczy
# 2572    George_Alfred_Henty
# 3002            John_Ruskin
# 287          R_M_Ballantyne
# 2288      Louisa_May_Alcott
# 1811       Sir_Walter_Scott
# 2678         William_J_Long
# 252     George_Alfred_Henty
# 190            D_H_Lawrence
# 542          Jonathan_Swift
# 2015      Washington_Irving
# 2967             Bret_Harte
# 1541            Henry_James
# 358     George_Alfred_Henty
# 1390        Rudyard_Kipling
# 892     George_Alfred_Henty
# 2144    George_Alfred_Henty
# 11      George_Alfred_Henty
#
#                                         2nd_Match_Title  \
# 56                              My_Terminal_Moraine.txt
# 1285                   Stories_of_Ships_and_the_Sea.txt
# 2177                             Guns_And_Snowshoes.txt
# 90                                The_Chosen_People.txt
# 1441                          Memoirs_of_a_Cavalier.txt
# 2973                     Dave_Porter_and_His_Double.txt
# 2325                               Arms_and_the_Man.txt
# 1922                                     Lay_Morals.txt
# 1930  The_Method_By_Which_The_Causes_Of_The_Present_...
# 244                                       Cleopatra.txt
# 1734                         The_Secret_of_the_Reef.txt
# 2787                                   Oak_Openings.txt
# 889                     The_Nest_of_the_Sparrowhawk.txt
# 2572                    A_Knight_of_the_White_Cross.txt
# 3002                        The_Philosophy_of_Style.txt
# 287                                Philosopher_Jack.txt
# 2288                                          Moods.txt
# 1811                         The_Fair_Maid_of_Perth.txt
# 2678                                Wilderness_Ways.txt
# 252                                    At_Agincourt.txt
# 190                      The_Forsyte_Saga,_Complete.txt
# 542   Critical_Miscellanies,_Volume_3,_Essay_1,_On_P...
# 2015                                        Tancred.txt
# 2967                                           Falk.txt
# 1541                                  Another_Sheaf.txt
# 358                           With_Moore_At_Corunna.txt
# 1390                      The_Great_Stone_of_Sardis.txt
# 892                           Through_Russian_Snows.txt
# 2144                          Through_Russian_Snows.txt
# 11                              The_Tiger_of_Mysore.txt
#
#             2nd_Match_Author  \
# 56    Frank_Richard_Stockton
# 1285             Jack_London
# 2177      Edward_Stratemeyer
# 90      Charlotte_Mary_Yonge
# 1441            Daniel_Defoe
# 2973      Edward_Stratemeyer
# 2325     George_Bernard_Shaw
# 1922  Robert_Louis_Stevenson
# 1930     Thomas_Henry_Huxley
# 244             Jacob_Abbott
# 1734         Harold_Bindloss
# 2787   James_Fenimore_Cooper
# 889          Baronness_Orczy
# 2572     George_Alfred_Henty
# 3002         Herbert_Spencer
# 287           R_M_Ballantyne
# 2288       Louisa_May_Alcott
# 1811        Sir_Walter_Scott
# 2678          William_J_Long
# 252      George_Alfred_Henty
# 190          John_Galsworthy
# 542              John_Morley
# 2015       Benjamin_Disraeli
# 2967           Joseph_Conrad
# 1541         John_Galsworthy
# 358      George_Alfred_Henty
# 1390  Frank_Richard_Stockton
# 892      George_Alfred_Henty
# 2144     George_Alfred_Henty
# 11       George_Alfred_Henty
#
#                                         3rd_Match_Title  \
# 56                                     A_Chosen_Few.txt
# 1285                                Treasure_Island.txt
# 2177                        Out_with_Gun_and_Camera.txt
# 90                           A_Book_of_Golden_Deeds.txt
# 1441                                     Richard_II.txt
# 2973                   Dave_Porter_and_the_Runaways.txt
# 2325                                The_Philanderer.txt
# 1922                       Two_Years_Ago,_Volume_II.txt
# 1930  The_Perpetuation_Of_Living_Beings,_Hereditary_...
# 244                             Alexander_the_Great.txt
# 1734                         The_Coast_of_Adventure.txt
# 2787                                 The_Pathfinder.txt
# 889                          The_Old_Curiosity_Shop.txt
# 2572                                 The_Boy_Knight.txt
# 3002                                    The_Teacher.txt
# 287                                     Sunk_at_Sea.txt
# 2288                                  Rose_in_Bloom.txt
# 1811                                      The_Abbot.txt
# 2678                        Northern_Trails,_Book_1.txt
# 252                         Saint_Bartholomew's_Eve.txt
# 190                                         Victory.txt
# 542                        Second_Thoughts_are_Best.txt
# 2015                          In_the_Wrong_Paradise.txt
# 2967                             By_Shore_and_Sedge.txt
# 1541                           Sketches_and_Studies.txt
# 358                                 One_of_the_28th.txt
# 1390                               Up_in_the_Clouds.txt
# 892                        The_Bravest_of_the_Brave.txt
# 2144                           With_Wolfe_in_Canada.txt
# 11                                For_Name_and_Fame.txt
#
#             3rd_Match_Author  \
# 56    Frank_Richard_Stockton
# 1285  Robert_Louis_Stevenson
# 2177      Edward_Stratemeyer
# 90      Charlotte_Mary_Yonge
# 1441            Jacob_Abbott
# 2973      Edward_Stratemeyer
# 2325     George_Bernard_Shaw
# 1922        Charles_Kingsley
# 1930     Thomas_Henry_Huxley
# 244             Jacob_Abbott
# 1734         Harold_Bindloss
# 2787   James_Fenimore_Cooper
# 889          Charles_Dickens
# 2572     George_Alfred_Henty
# 3002            Jacob_Abbott
# 287           R_M_Ballantyne
# 2288       Louisa_May_Alcott
# 1811        Sir_Walter_Scott
# 2678          William_J_Long
# 252      George_Alfred_Henty
# 190            Joseph_Conrad
# 542             Daniel_Defoe
# 2015             Andrew_Lang
# 2967              Bret_Harte
# 1541     Nathaniel_Hawthorne
# 358      George_Alfred_Henty
# 1390          R_M_Ballantyne
# 892      George_Alfred_Henty
# 2144     George_Alfred_Henty
# 11       George_Alfred_Henty
#
#                                         4th_Match_Title  \
# 56                                   The_Master_Key.txt
# 1285                      The_Cruise_of_the_Dazzler.txt
# 2177                 The_Rover_Boys_on_Land_and_Sea.txt
# 90                         The_Roman_and_the_Teuton.txt
# 1441                          Bonnie_Prince_Charlie.txt
# 2973                     The_Rover_Boys_in_Business.txt
# 2325                         The_Admirable_Crichton.txt
# 1922     The_May_Flower,_and_Miscellaneous_Writings.txt
# 1930                    The_Conditions_Of_Existence.txt
# 244                                Darius_the_Great.txt
# 1734                       Brandon_of_the_Engineers.txt
# 2787                              Miles_Wallingford.txt
# 889                               The_Tavern_Knight.txt
# 2572                       Saint_George_for_England.txt
# 3002                              Christian_Science.txt
# 287                                    A_Chosen_Few.txt
# 2288            Kitty's_Class_Day_And_Other_Stories.txt
# 1811                                  The_Monastery.txt
# 2678  A_Little_Brother_to_the_Bear_and_other_Animal_...
# 252                        With_Frederick_the_Great.txt
# 190                                      The_Return.txt
# 542        The_Lay-Man's_Sermon_upon_the_Late_Storm.txt
# 2015                              In_the_South_Seas.txt
# 2967                     A_Millionaire_of_Yesterday.txt
# 1541                        The_Beast_in_the_Jungle.txt
# 358                           Through_Russian_Snows.txt
# 1390                               Man_on_the_Ocean.txt
# 892                            With_Wolfe_in_Canada.txt
# 2144                               A_Jacobite_Exile.txt
# 11                                 On_the_Irrawaddy.txt
#
#                      4th_Match_Author  ...  \
# 56                   Lyman_Frank_Baum  ...
# 1285                      Jack_London  ...
# 2177               Edward_Stratemeyer  ...
# 90                   Charles_Kingsley  ...
# 1441              George_Alfred_Henty  ...
# 2973               Edward_Stratemeyer  ...
# 2325             James_Matthew_Barrie  ...
# 1922  Harriet_Elizabeth_Beecher_Stowe  ...
# 1930              Thomas_Henry_Huxley  ...
# 244                      Jacob_Abbott  ...
# 1734                  Harold_Bindloss  ...
# 2787            James_Fenimore_Cooper  ...
# 889                   Rafael_Sabatini  ...
# 2572              George_Alfred_Henty  ...
# 3002                       Mark_Twain  ...
# 287            Frank_Richard_Stockton  ...
# 2288                Louisa_May_Alcott  ...
# 1811                 Sir_Walter_Scott  ...
# 2678                   William_J_Long  ...
# 252               George_Alfred_Henty  ...
# 190                 Walter_de_la_Mare  ...
# 542                      Daniel_Defoe  ...
# 2015           Robert_Louis_Stevenson  ...
# 2967        Edward_Phillips_Oppenheim  ...
# 1541                      Henry_James  ...
# 358               George_Alfred_Henty  ...
# 1390                   R_M_Ballantyne  ...
# 892               George_Alfred_Henty  ...
# 2144              George_Alfred_Henty  ...
# 11                George_Alfred_Henty  ...
#
#                                         6th_Match_Title  \
# 56                The_Stories_of_the_Three_Burglars.txt
# 1285                                South_Sea_Tales.txt
# 2177                       The_Rover_Boys_on_a_Hunt.txt
# 90    Cameos_from_English_History,_from_Rollo_to_Edw...
# 1441        True_Stories_from_History_and_Biography.txt
# 2973                       The_Rover_Boys_on_a_Tour.txt
# 2325                                 The_Malefactor.txt
# 1922     Mosses_from_an_Old_Manse_and_Other_Stories.txt
# 1930                        On_the_Study_of_Zoology.txt
# 244                                 Cyrus_the_Great.txt
# 1734                        Johnstone_of_the_Border.txt
# 2787                                        The_Spy.txt
# 889                                 The_Lion's_Skin.txt
# 2572                        Friends,_though_divided.txt
# 3002                           Miscellaneous_Papers.txt
# 287                                Digging_for_Gold.txt
# 2288                                      Jo's_Boys.txt
# 1811                                        Ivanhoe.txt
# 2678                  The_Dog_Crusoe_and_his_Master.txt
# 252                             The_Cornet_of_Horse.txt
# 190                                Frontier_Stories.txt
# 542          And_What_if_the_Pretender_should_Come?.txt
# 2015  The_Works_of_Robert_Louis_Stevenson_-_Swanston...
# 2967  Colonel_Starbottle's_Client_and_Other_Stories.txt
# 1541              The_Ancestral_Footstep_(fragment).txt
# 358                               For_Name_and_Fame.txt
# 1390                               The_Variable_Man.txt
# 892                             At_Aboukir_and_Acre.txt
# 2144                                One_of_the_28th.txt
# 11                            Through_Russian_Snows.txt
#
#                6th_Match_Author  \
# 56       Frank_Richard_Stockton
# 1285                Jack_London
# 2177         Edward_Stratemeyer
# 90         Charlotte_Mary_Yonge
# 1441        Nathaniel_Hawthorne
# 2973         Edward_Stratemeyer
# 2325  Edward_Phillips_Oppenheim
# 1922        Nathaniel_Hawthorne
# 1930        Thomas_Henry_Huxley
# 244                Jacob_Abbott
# 1734            Harold_Bindloss
# 2787      James_Fenimore_Cooper
# 889             Rafael_Sabatini
# 2572        George_Alfred_Henty
# 3002            Charles_Dickens
# 287              R_M_Ballantyne
# 2288          Louisa_May_Alcott
# 1811           Sir_Walter_Scott
# 2678             R_M_Ballantyne
# 252         George_Alfred_Henty
# 190                  Bret_Harte
# 542                Daniel_Defoe
# 2015     Robert_Louis_Stevenson
# 2967                 Bret_Harte
# 1541        Nathaniel_Hawthorne
# 358         George_Alfred_Henty
# 1390        Philip_Kindred_Dick
# 892         George_Alfred_Henty
# 2144        George_Alfred_Henty
# 11          George_Alfred_Henty
#
#                                         7th_Match_Title  \
# 56                                 Digging_for_Gold.txt
# 1285                                  Wyndham's_Pal.txt
# 2177                   The_Rover_Boys_on_the_Plains.txt
# 90                     A_Child's_History_of_England.txt
# 1441                           Historical_Mysteries.txt
# 2973                            The_Missing_Tin_Box.txt
# 2325                           Anna_the_Adventuress.txt
# 1922                                           Dawn.txt
# 1930  A_Critical_Examination_Of_The_Position_Of_Mr._...
# 244                                    Genghis_Khan.txt
# 1734                           The_Buccaneer_Farmer.txt
# 2787                                   The_Pioneers.txt
# 889                               Uncle_Tom's_Cabin.txt
# 2572                              Winning_His_Spurs.txt
# 3002                                           Hume.txt
# 287                        Over_the_Rocky_Mountains.txt
# 2288                          An_Old-fashioned_Girl.txt
# 1811                                     Kenilworth.txt
# 2678                         The_God_of_His_Fathers.txt
# 252                        Saint_George_for_England.txt
# 190                      Far_from_the_Madding_Crowd.txt
# 542               On_the_Duty_of_Civil_Disobedience.txt
# 2015                                          Alroy.txt
# 2967                      To_Win_the_Love_He_Sought.txt
# 1541                                       Fanshawe.txt
# 358                  Commodore_Barney's_Young_Spies.txt
# 1390                       Lister's_Great_Adventure.txt
# 892                                   No_Surrender!.txt
# 2144                           Defending_the_Island.txt
# 11                      At_the_Point_of_the_Bayonet.txt
#
#                      7th_Match_Author  \
# 56                     R_M_Ballantyne
# 1285                  Harold_Bindloss
# 2177               Edward_Stratemeyer
# 90                    Charles_Dickens
# 1441                      Andrew_Lang
# 2973               Edward_Stratemeyer
# 2325        Edward_Phillips_Oppenheim
# 1922              Henry_Rider_Haggard
# 1930              Thomas_Henry_Huxley
# 244                      Jacob_Abbott
# 1734                  Harold_Bindloss
# 2787            James_Fenimore_Cooper
# 889   Harriet_Elizabeth_Beecher_Stowe
# 2572              George_Alfred_Henty
# 3002              Thomas_Henry_Huxley
# 287                    R_M_Ballantyne
# 2288                Louisa_May_Alcott
# 1811                 Sir_Walter_Scott
# 2678                      Jack_London
# 252               George_Alfred_Henty
# 190                      Thomas_Hardy
# 542               Henry_David_Thoreau
# 2015                Benjamin_Disraeli
# 2967        Edward_Phillips_Oppenheim
# 1541              Nathaniel_Hawthorne
# 358                        James_Otis
# 1390                  Harold_Bindloss
# 892               George_Alfred_Henty
# 2144                       James_Otis
# 11                George_Alfred_Henty
#
#                                    8th_Match_Title        8th_Match_Author  \
# 56    Jeff_Benson,_or_the_Young_Coastguardsman.txt          R_M_Ballantyne
# 1285                   Johnstone_of_the_Border.txt         Harold_Bindloss
# 2177           The_Rover_Boys_on_Treasure_Isle.txt      Edward_Stratemeyer
# 90              Historical_Lectures_and_Essays.txt        Charles_Kingsley
# 1441                  Old_Times_at_Otterbourne.txt    Charlotte_Mary_Yonge
# 2973            Dave_Porter_in_the_Gold_Fields.txt      Edward_Stratemeyer
# 2325                               Dear_Brutus.txt    James_Matthew_Barrie
# 1922                     From_Twice_Told_Tales.txt     Nathaniel_Hawthorne
# 1930                    On_the_Method_of_Zadig.txt     Thomas_Henry_Huxley
# 244                                    Pyrrhus.txt            Jacob_Abbott
# 1734                           Treasure_Island.txt  Robert_Louis_Stevenson
# 2787                                 The_Pilot.txt   James_Fenimore_Cooper
# 889                            The_Daisy_Chain.txt    Charlotte_Mary_Yonge
# 2572                        In_Freedom's_Cause.txt     George_Alfred_Henty
# 3002       The_Art_of_Writing_and_Other_Essays.txt  Robert_Louis_Stevenson
# 287                         Somebody's_Luggage.txt         Charles_Dickens
# 2288                              Little_Women.txt       Louisa_May_Alcott
# 1811                               Redgauntlet.txt        Sir_Walter_Scott
# 2678            Love_of_Life_and_Other_Stories.txt             Jack_London
# 252                           A_Jacobite_Exile.txt     George_Alfred_Henty
# 190                  An_Outcast_of_the_Islands.txt           Joseph_Conrad
# 542              A_Plea_for_Captain_John_Brown.txt     Henry_David_Thoreau
# 2015             Abbotsford_and_Newstead_Abbey.txt       Washington_Irving
# 2967                    In_the_Carquinez_Woods.txt              Bret_Harte
# 1541                  A_Traveler_from_Altruria.txt    William_Dean_Howells
# 358                                Jack_Archer.txt     George_Alfred_Henty
# 1390                                     Youth.txt           Joseph_Conrad
# 892                       In_the_Irish_Brigade.txt     George_Alfred_Henty
# 2144                     With_Moore_At_Corunna.txt     George_Alfred_Henty
# 11                            A_Jacobite_Exile.txt     George_Alfred_Henty
#
#                                         9th_Match_Title  \
# 56                                   Rollo's_Museum.txt
# 1285                            Kit_Musgrave's_Luck.txt
# 2177                        First_at_the_North_Pole.txt
# 90     History_of_Friedrich_II_of_Prussia,_Volume_2.txt
# 1441                             In_Freedom's_Cause.txt
# 2973                  The_Young_Oarsmen_of_Lakeview.txt
# 2325                         What_Every_Woman_Knows.txt
# 1922                              Weir_of_Hermiston.txt
# 1930                       The_Darwinian_Hypothesis.txt
# 244                          King_Alfred_of_England.txt
# 1734                                   Thrice_Armed.txt
# 2787                                 Homeward_Bound.txt
# 889                           The_Young_Step-Mother.txt
# 2572                                   At_Agincourt.txt
# 3002                              The_Vital_Message.txt
# 287    Winsome_Winnie_and_other_New_Nonsense_Novels.txt
# 2288                          A_Bride_of_the_Plains.txt
# 1811                                  The_Betrothed.txt
# 2678       Brown_Wolf_and_Other_Jack_London_Stories.txt
# 252   By_Pike_and_Dyke:__A_Tale_of_the_Rise_of_the_D...
# 190                                        Lord_Jim.txt
# 542                    Essays_on_Censorship_and_Art.txt
# 2015                                        Lothair.txt
# 2967                             The_Three_Partners.txt
# 1541                Time_and_Tide_by_Weare_and_Tyne.txt
# 358                             With_Clive_in_India.txt
# 1390                      Danger!_and_Other_Stories.txt
# 892   By_Pike_and_Dyke:__A_Tale_of_the_Rise_of_the_D...
# 2144                        Through_Three_Campaigns.txt
# 11                              With_Clive_in_India.txt
#
#             9th_Match_Author  \
# 56              Jacob_Abbott
# 1285         Harold_Bindloss
# 2177      Edward_Stratemeyer
# 90            Thomas_Carlyle
# 1441     George_Alfred_Henty
# 2973      Edward_Stratemeyer
# 2325    James_Matthew_Barrie
# 1922  Robert_Louis_Stevenson
# 1930     Thomas_Henry_Huxley
# 244             Jacob_Abbott
# 1734         Harold_Bindloss
# 2787   James_Fenimore_Cooper
# 889     Charlotte_Mary_Yonge
# 2572     George_Alfred_Henty
# 3002  Sir_Arthur_Conan_Doyle
# 287          Stephen_Leacock
# 2288         Baronness_Orczy
# 1811        Sir_Walter_Scott
# 2678             Jack_London
# 252      George_Alfred_Henty
# 190            Joseph_Conrad
# 542          John_Galsworthy
# 2015       Benjamin_Disraeli
# 2967              Bret_Harte
# 1541             John_Ruskin
# 358      George_Alfred_Henty
# 1390  Sir_Arthur_Conan_Doyle
# 892      George_Alfred_Henty
# 2144     George_Alfred_Henty
# 11       George_Alfred_Henty
#
#                                        10th_Match_Title  \
# 56     Amos_Kilbright;_His_Adscititious_Experiences.txt
# 1285                            Fighting_the_Whales.txt
# 2177                      Dave_Porter_at_Star_Ranch.txt
# 90            Lectures_Delivered_in_America_in_1874.txt
# 1441                                The_Little_Duke.txt
# 2973                              Teddy_and_Carrots.txt
# 2325                          Alice_Sit-By-The-Fire.txt
# 1922                                 Shapes_of_Clay.txt
# 1930  William_Harvey_And_The_Discovery_Of_The_Circul...
# 244                                         Romulus.txt
# 1734                          The_Lure_of_the_North.txt
# 2787                               The_Two_Admirals.txt
# 889                    The_Pillars_of_the_House,_V1.txt
# 2572                          Bonnie_Prince_Charlie.txt
# 3002                         Essays_on_Paul_Bourget.txt
# 287                                 Chasing_the_Sun.txt
# 2288     The_May_Flower,_and_Miscellaneous_Writings.txt
# 1811                                  Guy_Mannering.txt
# 2678                                    Before_Adam.txt
# 252                           Through_Russian_Snows.txt
# 190                                  Dombey_and_Son.txt
# 542                       How_to_Fail_in_Literature.txt
# 2015                        The_Prince_and_the_Page.txt
# 2967                   Heart_of_Darkness,_Version_2.txt
# 1541                               The_Jolly_Corner.txt
# 358                               Maori_and_Settler.txt
# 1390                Dutch_Courage_and_Other_Stories.txt
# 892                                Orange_and_Green.txt
# 2144                   With_Kitchener_in_the_Soudan.txt
# 11                            With_Moore_At_Corunna.txt
#
#                     10th_Match_Author
# 56             Frank_Richard_Stockton
# 1285                   R_M_Ballantyne
# 2177               Edward_Stratemeyer
# 90                   Charles_Kingsley
# 1441             Charlotte_Mary_Yonge
# 2973                       James_Otis
# 2325             James_Matthew_Barrie
# 1922                   Ambrose_Bierce
# 1930              Thomas_Henry_Huxley
# 244                      Jacob_Abbott
# 1734                  Harold_Bindloss
# 2787            James_Fenimore_Cooper
# 889              Charlotte_Mary_Yonge
# 2572              George_Alfred_Henty
# 3002                       Mark_Twain
# 287                    R_M_Ballantyne
# 2288  Harriet_Elizabeth_Beecher_Stowe
# 1811                 Sir_Walter_Scott
# 2678                      Jack_London
# 252               George_Alfred_Henty
# 190                   Charles_Dickens
# 542                       Andrew_Lang
# 2015             Charlotte_Mary_Yonge
# 2967                    Joseph_Conrad
# 1541                      Henry_James
# 358               George_Alfred_Henty
# 1390                      Jack_London
# 892               George_Alfred_Henty
# 2144              George_Alfred_Henty
# 11                George_Alfred_Henty
#
# [30 rows x 22 columns]

# %%
df_neighbors.loc[df_neighbors['Query_Author'] == 'Eugene O_Neill']
#df_neighbors.sort_values(by=['Query_Title'], ascending=False).head(30)
# Out:
#             Query_Title    Query_Author            1st_Match_Title  \
# 181   Anna Christie.txt  Eugene O_Neill         Ship's Company.txt
# 248       The Straw.txt  Eugene O_Neill  Alice Sit-By-The-Fire.txt
# 617   The Hairy Ape.txt  Eugene O_Neill          Anna Christie.txt
# 1064  The First Man.txt  Eugene O_Neill        The Philanderer.txt
#
#            1st_Match_Author    2nd_Match_Title     2nd_Match_Author  \
# 181   William Wymark Jacobs      The Straw.txt       Eugene O_Neill
# 248    James Matthew Barrie        Candida.txt  George Bernard Shaw
# 617          Eugene O_Neill  Prairie Folks.txt       Hamlin Garland
# 1064    George Bernard Shaw        Candida.txt  George Bernard Shaw
#
#                     3rd_Match_Title       3rd_Match_Author    4th_Match_Title  \
# 181              Light Freights.txt  William Wymark Jacobs  The Hairy Ape.txt
# 248                 Dear Brutus.txt   James Matthew Barrie  Short Cruises.txt
# 617   Six Short Plays, Complete.txt        John Galsworthy  A Bit O' Love.txt
# 1064      Alice Sit-By-The-Fire.txt   James Matthew Barrie    Dear Brutus.txt
#
#            4th_Match_Author  ...                        6th_Match_Title  \
# 181          Eugene O_Neill  ...                          Odd Craft.txt
# 248   William Wymark Jacobs  ...             The Admirable Crichton.txt
# 617         John Galsworthy  ...                    The Foundations.txt
# 1064   James Matthew Barrie  ...  Behind A Mask, Or A Woman's Power.txt
#
#            6th_Match_Author                7th_Match_Title  \
# 181   William Wymark Jacobs  Six Short Plays, Complete.txt
# 248    James Matthew Barrie          Echoes of the War.txt
# 617         John Galsworthy    The Story of the Gadsby.txt
# 1064      Louisa May Alcott             Quality Street.txt
#
#           7th_Match_Author             8th_Match_Title       8th_Match_Author  \
# 181        John Galsworthy   The Lady of the Barge.txt  William Wymark Jacobs
# 248   James Matthew Barrie               Odd Craft.txt  William Wymark Jacobs
# 617        Rudyard Kipling          Soldiers Three.txt        Rudyard Kipling
# 1064  James Matthew Barrie  What Every Woman Knows.txt   James Matthew Barrie
#
#                                         9th_Match_Title  \
# 181                                    More Cargoes.txt
# 248                           The Lady of the Barge.txt
# 617                  Phantasmagoria and Other Poems.txt
# 1064  The Abbot's Ghost, Or Maurice Treherne's Tempt...
#
#            9th_Match_Author                              10th_Match_Title  \
# 181   William Wymark Jacobs                              Many Cargoes.txt
# 248   William Wymark Jacobs                    What Every Woman Knows.txt
# 617           Lewis Carroll  Adventures of Huckleberry Finn, Complete.txt
# 1064      Louisa May Alcott                               Misalliance.txt
#
#           10th_Match_Author
# 181   William Wymark Jacobs
# 248    James Matthew Barrie
# 617              Mark Twain
# 1064    George Bernard Shaw
#
# [4 rows x 22 columns]

# %% [markdown]
# ### Neighbors Search on UMAP Embeddings, Euclidean Metric

# %%
umap_embs = author_label_df[['umap_1', 'umap_2']].values.tolist()
neighbors = NearestNeighbors(n_neighbors=11, metric='euclidean').fit(umap_embs)
distances, inds = neighbors.kneighbors(umap_embs)
full_neighbors = []
for idx in range(inds.shape[0]):
    sub_inds = inds[idx, :].tolist()
    df_author_and_works = v2_author_df.iloc[sub_inds, 1:3]
    authors = df_author_and_works['author'].values
    works = df_author_and_works['work'].values
    authors_and_works = np.column_stack((works, authors)).tolist()
    row_neighbors = []
    for row in authors_and_works:
        row_neighbors.extend(row)
      
    full_neighbors.append(row_neighbors)

#random.shuffle(full_neighbors)
df_neighbors = pd.DataFrame(
    full_neighbors,
    columns=[
        'Query_Title', 'Query_Author',
        '1st_Match_Title', '1st_Match_Author',
        '2nd_Match_Title', '2nd_Match_Author',
        '3rd_Match_Title', '3rd_Match_Author',
        '4th_Match_Title', '4th_Match_Author',
        '5th_Match_Title', '5th_Match_Author',
        '6th_Match_Title', '6th_Match_Author',
        '7th_Match_Title', '7th_Match_Author',
        '8th_Match_Title', '8th_Match_Author',
        '9th_Match_Title', '9th_Match_Author',
        '10th_Match_Title', '10th_Match_Author',
    ]
)
#df_neighbors.head(20)
df_neighbors.sort_values(by=['Query_Title'], ascending=False).head(30)

# %% [markdown]
# ### Neighbors Search on UMAP Embeddings, Cosine Metric

# %%
umap_embs = author_label_df[['umap_1', 'umap_2']].values.tolist()
neighbors = NearestNeighbors(n_neighbors=11, metric='cosine').fit(umap_embs)
distances, inds = neighbors.kneighbors(umap_embs)
full_neighbors = []
for idx in range(inds.shape[0]):
    sub_inds = inds[idx, :].tolist()
    df_author_and_works = v2_author_df.iloc[sub_inds, 1:3]
    authors = df_author_and_works['author'].values
    works = df_author_and_works['work'].values
    authors_and_works = np.column_stack((works, authors)).tolist()
    row_neighbors = []
    for row in authors_and_works:
        row_neighbors.extend(row)
      
    full_neighbors.append(row_neighbors)

#random.shuffle(full_neighbors)
df_neighbors = pd.DataFrame(
    full_neighbors,
    columns=[
        'Query_Title', 'Query_Author',
        '1st_Match_Title', '1st_Match_Author',
        '2nd_Match_Title', '2nd_Match_Author',
        '3rd_Match_Title', '3rd_Match_Author',
        '4th_Match_Title', '4th_Match_Author',
        '5th_Match_Title', '5th_Match_Author',
        '6th_Match_Title', '6th_Match_Author',
        '7th_Match_Title', '7th_Match_Author',
        '8th_Match_Title', '8th_Match_Author',
        '9th_Match_Title', '9th_Match_Author',
        '10th_Match_Title', '10th_Match_Author',
    ]
)
#df_neighbors.head(30)
df_neighbors.sort_values(by=['Query_Title'], ascending=False).head(30)
