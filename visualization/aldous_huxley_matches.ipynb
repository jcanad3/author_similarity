# %%
import pandas as pd

# %%
df_neighbors = pd.read_csv('df_neighbors.csv')
df_aldous = df_neighbors.loc[df_neighbors['Query_Author'] == 'Aldous_Huxley']
df_aldous
# Out:
#                               Query_Title   Query_Author  \
# 1260                         Crome_Yellow  Aldous_Huxley
# 1261  The_Defeat_of_Youth_and_Other_Poems  Aldous_Huxley
# 1262                         Mortal_Coils  Aldous_Huxley
#
#                                    1st_Match_Title      1st_Match_Author  \
# 1260             John_Ingerfield_and_Other_Stories  Jerome_Klapka_Jerome
# 1261  The_Suppressed_Poems_of_Alfred_Lord_Tennyson         Lord_Tennyson
# 1262                                Tatterdemalion       John_Galsworthy
#
#                     2nd_Match_Title   2nd_Match_Author  \
# 1260         The_Ball_and_The_Cross     G_K_Chesterton
# 1261  The_Listeners_and_Other_Poems  Walter_de_la_Mare
# 1262                   Crome_Yellow      Aldous_Huxley
#
#                               3rd_Match_Title 3rd_Match_Author  \
# 1260                    Drift_from_Two_Shores       Bret_Harte
# 1261  The_Early_Poems_of_Alfred_Lord_Tennyson    Lord_Tennyson
# ...
